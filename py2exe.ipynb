# %%
# coding:utf-8
import sys
#imp.reload(sys)
import importlib
importlib.reload(sys)
#sys.setdefaultencoding('utf-8')
#reload(sys)
#sys.setdefaultencoding('utf8')
#  __author__ = '郭 璞'
#  __date__ = '2016/8/4'
#  __Desc__ = 一个可以将图片转换成终端字符形式的小工具

from time import *
import image
class ImageTool():

  def __init__(self):
    print('Initialization Completed! @',ctime());

  def getChars(self,image_pixels,image_width,image_height):
    replace_chars = 'ABCDEFGHIJKLMNO '
    terminal_chars = ''
    for h in xrange(image_height):
      for w in xrange(image_width):
        point_pixel = image_pixels[w,h]
        terminal_chars +=replace_chars[int(sum(point_pixel)/3.0/256.0*16)]
      terminal_chars+='\n'
    return terminal_chars

  def formatImage(self,imagename,image_width,image_height):
    img = Image.open(imagename,'rb')
    if img.mode != 'RGB':
      img = img.convert('RGB')
    w,h = img.size
    rw = image_width*1.0/w
    rh = image_height*1.0/h
    r = rw if rw<rh else rh
    rw = int(r*w)
    rh = int(r*h)
    img = img.resize((rw,rh),Image.ANTIALIAS)
    return img

  def entrance(self,image_path,out_width,out_height):
    image = self.formatImage(imagename=image_path,image_width=out_width,image_height=out_height)
    image_pixels = image.load()
    out_width ,out_height = image.size
    terminal_chars = self.getChars(image_pixels=image_pixels,image_width=out_width,image_height=out_height)

if __name__ == "__main__":
  tool = ImageTool()
  imagename = sys.argv[1]
  w = int(sys.argv[2])
  h = int(sys.argv[3])
  tool.entrance(imagename,w,h)
# Out:
# Initialization Completed! @ Wed Nov  7 22:25:23 2018
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-fcce1c493a4e> in <module>()
#      50   tool = ImageTool()
#      51   imagename = sys.argv[1]
# ---> 52   w = int(sys.argv[2])
#      53   h = int(sys.argv[3])
#      54   tool.entrance(imagename,w,h)
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\admin\\AppData\\Roaming\\jupyter\\runtime\\kernel-6af45c38-7485-46e4-b50f-1a71acf471e1.json'

# %%
import image
a = "\u6211";
print(a);
# Out:
# 我

# %%
import requests as req
from PIL import Image
from io import BytesIO
#img_src = 'http://wx2.sinaimg.cn/mw690/ac38503ely1fesz8m0ov6j20qo140dix.jpg';
img_src = 'https://content.screencast.com/users/aa1411/folders/Snagit/media/b6d170c9-aa13-41f3-beba-c19acb51c4f4/11.07.2018-23.03.jpg';
#img_src = 'https://image.baidu.com/search/detail?ct=503316480&z=0&ipn=false&word=%E5%8D%8E%E6%99%A8%E5%AE%87%E7%85%A7%E7%89%87&hs=2&pn=0&spn=0&di=136533274020&pi=0&rn=1&tn=baiduimagedetail&is=0%2C0&ie=utf-8&oe=utf-8&cl=2&lm=-1&cs=3348109351%2C3683603701&os=3299581586%2C340848212&simid=0%2C0&adpicid=0&lpn=0&ln=30&fr=ala&fm=&sme=&cg=star&bdtype=0&oriquery=%E5%8D%8E%E6%99%A8%E5%AE%87%E7%85%A7%E7%89%87&objurl=http%3A%2F%2Fgss0.baidu.com%2F-4o3dSag_xI4khGko9WTAnF6hhy%2Fzhidao%2Fpic%2Fitem%2F00e93901213fb80ef777a48b34d12f2eb83894cc.jpg&fromurl=ippr_z2C%24qAzdH3FAzdH3Fzit1w5_z%26e3Bkwt17_z%26e3Bv54AzdH3Fq7jfpt5gAzdH3Fm8malnaca8900a9lnd_z%26e3Bip4s&gsm=0&islist=&querylist=';
response = req.get(img_src)
image = Image.open(BytesIO(response.content))
image.show()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# D:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#
# D:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      59
# ---> 60     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61         af, socktype, proto, canonname, sa = res
#
# D:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     744     addrlist = []
# --> 745     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     746         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
from skimage import io
img_src = 'http://wx2.sinaimg.cn/mw690/ac38503ely1fesz8m0ov6j20qo140dix.jpg';
#img_src = 'https://image.baidu.com/search/detail?ct=503316480&z=0&ipn=false&word=%E5%8D%8E%E6%99%A8%E5%AE%87%E7%85%A7%E7%89%87&hs=2&pn=0&spn=0&di=136533274020&pi=0&rn=1&tn=baiduimagedetail&is=0%2C0&ie=utf-8&oe=utf-8&cl=2&lm=-1&cs=3348109351%2C3683603701&os=3299581586%2C340848212&simid=0%2C0&adpicid=0&lpn=0&ln=30&fr=ala&fm=&sme=&cg=star&bdtype=0&oriquery=%E5%8D%8E%E6%99%A8%E5%AE%87%E7%85%A7%E7%89%87&objurl=http%3A%2F%2Fgss0.baidu.com%2F-4o3dSag_xI4khGko9WTAnF6hhy%2Fzhidao%2Fpic%2Fitem%2F00e93901213fb80ef777a48b34d12f2eb83894cc.jpg&fromurl=ippr_z2C%24qAzdH3FAzdH3Fzit1w5_z%26e3Bkwt17_z%26e3Bv54AzdH3Fq7jfpt5gAzdH3Fm8malnaca8900a9lnd_z%26e3Bip4s&gsm=0&islist=&querylist=';
image = io.imread(img_src)
io.imshow(image)
io.show()
# Out:
# D:\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
# D:\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:1400: MatplotlibDeprecationWarning: The 'box-forced' keyword argument is deprecated since 2.2.
#   " since 2.2.", cbook.mplDeprecation)

# %%
# -*- coding: utf-8 -*-
import numpy as np
import urllib.request
import cv2
 
# URL到图片
def url_to_image(url):
    # download the image, convert it to a NumPy array, and then read
    # it into OpenCV format
    resp = urllib.request.urlopen(url)
    # bytearray将数据转换成（返回）一个新的字节数组
    # asarray 复制数据，将结构化数据转换成ndarray
    image = np.asarray(bytearray(resp.read()), dtype="uint8")
    # cv2.imdecode()函数将数据解码成Opencv图像格式
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    # return the image
    return image
 
# initialize the list of image URLs to download
urls = [
    "https://www.screencast.com/t/7jeFzlxQ"
    #"http://www.pyimagesearch.com/wp-content/uploads/2015/01/google_logo.png"
]
 
# loop over the image URLs
for url in urls:
    # download the image URL and display it
    print("downloading %s" % (url));
    image = url_to_image(url)
    cv2.imshow("Image", image)
    cv2.waitKey(0)
# Out:
# downloading https://www.screencast.com/t/7jeFzlxQ
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-37-553785e2ad37> in <module>()
#      28     print("downloading %s" % (url));
#      29     image = url_to_image(url)
# ---> 30     cv2.imshow("Image", image)
#      31     cv2.waitKey(0)
#
# error: OpenCV(3.4.2) D:\Build\OpenCV\opencv-3.4.2\modules\highgui\src\window.cpp:364: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'

# %%
import urllib.request
#print(urllib.__file__)
def getHtml(url):
    page = urllib.request.urlopen(url)
    html = page.read()
    return html
 e
html = getHtml("http://www.baidu.com")
 
print(html)
# Out:
#   File "<ipython-input-47-af26601de242>", line 7
#     e
#      ^
# IndentationError: unindent does not match any outer indentation level

# %%
from urllib import request
pic_link = 'https://content.screencast.com/users/aa1411/folders/Snagit/media/b6d170c9-aa13-41f3-beba-c19acb51c4f4/11.07.2018-23.03.jpg'
save_path = r'd:\HCY.jpg'
try:
    request.urlretrieve(pic_link, save_path)
except:
    pass
from PIL import Image
img_src = save_path;
im = Image.open(img_src)
im.show()

# %%
1+2
# Out:
# 3

# %%
from PIL import Image
im = Image.open("D:\\TTF\\Photograph\\福利图\03.jpg")
pix = im.load()
width = im.size[0]
height = im.size[1]
for x in range(width):
    for y in range(height):
        r, g, b = pix[x, y]
        print(r, g, b)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-efc8d82fb440> in <module>()
#       1 from PIL import Image
# ----> 2 im = Image.open("D:\\TTF\\Photograph\\福利图\03.jpg")
#       3 pix = im.load()
#       4 width = im.size[0]
#       5 height = im.size[1]
#
# D:\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2546
#    2547     if filename:
# -> 2548         fp = builtins.open(filename, "rb")
#    2549         exclusive_fp = True
#    2550
#
# OSError: [Errno 22] Invalid argument: 'D:\\TTF\\Photograph\\福利图\x03.jpg'

# %%
print("\
      \u5728\u6b64\u5e76\u518d\u6b21\n\
      \u795d\n\
      \u5927\u68a6\u5b50\n\
      \u7834\u58f3\u65e5\u5feb\u4e50\n\
      \u751f\u65e5\u5feb\u4e50\n\
      \u4f5c\u4e3a\u4e00\u540d\u300a\u5bd2\u9e26\u5c11\u5e74\u300b\uff0c\u6211\u4eec\u4e0d\u662f\u300a\u65e0\u804a\u4eba\u300b\uff0c\u66f4\u4e0d\u662f\u300a\u667a\u5546\u4e8c\u4e94\u96f6\u300b\uff0c\u6216\u8bb8\u6709\u4eba\u89c9\u5f97\u6211\u4eec\u662f\u300a\u5f02\n\
      \u7c7b\u300b\uff0c\u4f46\u6211\u4eec\u4f1a\u8bf4\u300a\u6211\u7ba1\u4f60\u300b\u3002\u540c\u5728\u300a\u9020\u7269\u8005\u300b\u7684\u4e16\u754c\u91cc\u6211\u4eec\u6709\u81ea\u5df1\u7684\u601d\u60f3\uff0c\u53ea\u4e0d\u8fc7\u6211\u6d3b\u51fa\u300a\u6a2a\u51b2\n\
#       心里还在嘀咕着他们《Why Nobody Fights》，《趁你还年轻》,我们要奋斗，我们要做自己的《拆
#       弹专家》，排除自己内心不好的东西，让《消失的昨天》《For Forever》不再重现，在伤心我们为
#       何不在夏天快走之际一起《嗨夏》，来一场《夏之旅》，做一个《不朽》的传奇。尽管我们对宇宙
#       来说就是《烟火里的尘埃》，但我们要活出自己的范。

# %%
#coding:utf-8
import time
start = time.clock()
import os
#import time
import pygame
import random
from PIL import Image
from urllib import request
def Get_Url(number):
    numbers = {
        1 : 'https://content.screencast.com/users/aa1411/folders/Snagit/media/c9dc7ece-0c3a-4c0b-8942-3b448e4372bb/01.14.2019-15.57.jpg',
        2 : 'https://content.screencast.com/users/aa1411/folders/Snagit/media/2d7e2f80-703e-4196-af03-3989e5ca4e95/01.14.2019-19.46.png',
        3 : 'https://content.screencast.com/users/aa1411/folders/Snagit/media/f7e16ef8-3b47-4adc-885e-856e981cca95/01.14.2019-18.35.png',
    }
    return numbers.get(number,None)
def Snow():
    # 初始化
    pygame.init()
    
    SIZE = (1090,776)
    screen = pygame.display.set_mode(SIZE)
    pygame.display.set_caption("赵春梦生日快乐")
    # 加载背景图
    # 图片路径格式为 ： xxx:/xxx/xxx.jpg 或  xxx:\\xxx\\xxx.jpg
    background = pygame.image.load("D:\\ZYL.jpg")
    
    # 定义一个雪花列表
    snow = []
    # 初始化雪花
    
    for i in range(300):
        x = random.randrange(0,SIZE[0])
        y = random.randrange(0,SIZE[1])
        speedx = random.randint(-1,2)
        speedy = random.randint(3,8)
        snow.append([x,y,speedx,speedy])
    
    done = False
    while not done:
        # 消息事件循环，判断推出
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                done = True
        # 绘制位图
        screen.blit(background,(0,0))

        # 雪花列表循环
        for i in range(len(snow)):
            # 绘制雪花。颜色，位置，大小
            pygame.draw.circle(screen,(255,255,255),snow[i][:2],snow[i][3])

            # 移动雪花位置（下一次循环起效）
            snow[i][0] += snow[i][2]
            snow[i][1] += snow[i][3]

            # 如果雪花落出屏幕，重设位置
            if snow[i][1] > SIZE[1]:
                snow[i][1] = random.randrange(-50,-10)
                snow[i][0] = random.randrange(0,SIZE[0])
        pygame.display.flip()
    pygame.quit()
if __name__ == "__main__":
    for i in [1,2,3,4]:
        if i < 4:
            pic_link = Get_Url(i)
            save_path = r'd:\ZYL.jpg'
            try:
                request.urlretrieve(pic_link, save_path)
            except:
                pass
            if i < 3:
                im = Image.open(save_path)
                im.show()
                os.remove(r'd:\ZYL.jpg')
                time.sleep(10)
        else:
            Snow()
            a = input("End")
    end = time.clock()
    print("Running time:%s"%(end-start))
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# End
# Running time:272.39112777563173

# %% [markdown]
# 祝
# 赵春梦
# 生日快乐
# And Happy New Year To You!
# 在《恒星》里尽情《时间飞行》的你，看着《地星撞海星》，或许《疯狂的爱》促使这颗地星对那个海星《许你》

# %%
import cv2
image=cv2.imread("D:\TTF\Photograph\Y.jpg")
print("width: %d pixels" % (image.shape[1]))
# Out:
# width: 361 pixels
